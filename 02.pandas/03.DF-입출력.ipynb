# %%
#파일 입출력
import numpy as np
import pandas as pd
# Out:
# UsageError: Line magic function `%%writefile` not found.

# %%
# %%writefile sample1.csv
# c1,c2,c3
# 1,1.11,one
# 2,2.22,two
# 3,3.33,three
# Out:
# Writing sample1.csv

# %%
df=pd.read_csv("sample1.csv")#read_csv() 파일 읽기

df['c4']=['일','이','삼']
df.to_csv("sample2.csv")     #파일쓰기 ,인덱스값이 들어감
pd.read_csv("sample2.csv")
# Out:
#    Unnamed: 0  c1    c2     c3 c4
# 0           0   1  1.11    one  일
# 1           1   2  2.22    two  이
# 2           2   3  3.33  three  삼

# %%
#파일에 쓸 때는 index=False 옵션을 줄 것
df.to_csv("sample3.csv",index=False)    #index=Null 인덱스 값을 넣지않음
pd.read_csv("sample3.csv")

# %%
#sample4.tsv
#Encoding: EUC-kr
# Separator : \t
# 쓸데없는줄이 처음에 한개 있음
df=pd.read_csv("sample4.tsv",sep='\t',skiprows=1,encoding="ANSI")
df
# Out:
#    1 2 3 4
# 0  A B C D

# %%
price=["1,000","3,300","5,000"]
list(map(lambda x:int(x.replace(",","")),price))
# == pd.read_csv(thousands=',') -> ',' 지우기
# Out:
# [1000, 3300, 5000]

# %%
df=pd.read_csv("서울시CCTV설치운영현황(자치구)_년도별_211231기준 (1).csv",encoding="EUC-KR",skiprows=1,thousands=',')
df["2012년"].fillna("없어",inplace=True)
df
# Out:
#       구분     총계  2012년 이전   2012년   2013년  2014년  2015년  2016년  2017년  2018년  \
# 0      계  83557      4812  1851.0  3434.0   4295   6840   8708  11572  10627
# 1    종로구   1715       815      없어     NaN    195    150      0    261     85
# 2    중 구   2447        16   114.0    87.0     77    236    240    372    386
# 3    용산구   2611        34    71.0   234.0    125    221    298    351    125
# 4    성동구   3829       163   144.0   208.0    107    325    255    967    415
# 5    광진구   3211        35    57.0   100.0    187     98     52    675    465
# 6   동대문구   2628         4     0.0    14.0     16    115    804    814    201
# 7    중랑구   3737       346    21.0   253.0     72    132    155    153    174
# 8    성북구   4602        81    78.0   170.0    229    322    594    890    867
# 9    강북구   3090         8     0.0    22.0     61    124    251     29    391
# 10   도봉구   1930       128    22.0     2.0    145    172    123    129    222
# ...
